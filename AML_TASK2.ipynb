# %%
# !rm -rf task2_aml
# !git clone https://USERNAME_GITHUB:DEVELOPER_KEY_GITHUB@github.com/danielerussica/task2_aml

# %%
# opzionale per vedere training curves
# !wandb login API_KEY_WANDB

# %%
# dataset salvato in mv_data
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install torchmetrics

# %%
# [OPTIONAL] Train bbox model first (only if you don't have a pretrained one)
# Add --train_bbox flag to train the bbox model
# !python task2_aml/main.py \
    --path /content/drive/MyDrive/mv_data \
    --save_path task2_aml/models \
    --preprocessed_dir /content/drive/MyDrive/mv_data/preprocessed \
    --filter_frames /content/drive/MyDrive/mv_data/kept_frames.pt \
    --rnmf_dir /content/drive/MyDrive/mv_data/rnmf_processed \
    --bbox_model_dir task2_aml/models/bbox \
    --train_bbox

# %%
# Train segmentation model using PRECOMPUTED bboxes from cell 6
# This will:
# 1. Load precomputed bboxes from /content/bbox_output (generated by generate_bbox.py)
# 2. Filter all videos using these saved bboxes
# 3. Train segmentation UNet (UNetSE with temporal context + RNMF)
# 4. Generate predictions for test set and create submission.csv
# !python task2_aml/main.py \
    --path /content/drive/MyDrive/mv_data \
    --save_path task2_aml/models \
    --preprocessed_dir /content/drive/MyDrive/mv_data/preprocessed \
    --filter_frames /content/drive/MyDrive/mv_data/kept_frames.pt \
    --rnmf_dir /content/drive/MyDrive/mv_data/rnmf_processed \
    --precomputed_bbox_dir /content/bbox_output

# %%
# Generate bounding boxes for test videos and save GIFs for visualization
# Saving to local /content/ path (writable), not Google Drive (may be read-only)
# !python task2_aml/generate_bbox.py \
    --path /content/drive/MyDrive/mv_data \
    --preprocessed_dir /content/drive/MyDrive/mv_data/preprocessed \
    --bbox_model_path task2_aml/models/bbox/model.pth \
    --output_dir /content/bbox_output \
    --gif_dir /content/bbox_gifs
